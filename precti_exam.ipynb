# %%
import matplotlib.pyplot as plt
import numpy as np
xpoint=np.array([3,5])
ypoint=np.array([4,8])
plt.plot(xpoint,ypoint)
plt.show()

# %%
import matplotlib.pyplot as plt
data=[]
time=[]
plt.plot(data,time,marker='',linestyle='',linewidth=)
plt.xlabel("",color,size)
plt.ylabel("",color,size)
plt.title("",loc="",color,size)
plt.grid()
plt.yticks(time)
plt.xticks(visible=True)
plt.legend(loc="",shadow=,fontsize=)
plt.show()
