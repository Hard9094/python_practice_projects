# %%
#concatination of data
import pandas as pd
df=pd.read_csv("weather_1.csv")
df
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 6    6:51 AM          28.9        26.1        89                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# ...

# %%
df1=pd.DataFrame({
    'Name':["sneha","siddha","cheri","femi"],
    'subname':["cn","pds","math","se"],
    'marks':[60,60,60,60]
},
index=[1,2,3,4])
df1
# Out:
#      Name subname  marks
# 1   sneha      cn     60
# 2  siddha     pds     60
# 3   cheri    math     60
# 4    femi      se     60

# %%
df2=pd.DataFrame({
    'Name':["vidhi","diya","sneha","haha"],
    'subname':["cn","pds","math","se"],
    'marks':[59,59,59,59]
},
index=[1,2,3,4])
df2
# Out:
#     Name subname  marks
# 1  vidhi      cn     59
# 2   diya     pds     59
# 3  sneha    math     59
# 4   haha      se     59

# %%
pd.concat([df1,df2])
# Out:
#      Name subname  marks
# 1   sneha      cn     60
# 2  siddha     pds     60
# 3   cheri    math     60
# 4    femi      se     60
# 1   vidhi      cn     59
# 2    diya     pds     59
# 3   sneha    math     59
# 4    haha      se     59

# %%
pd.concat([df1,df2],ignore_index=True)
# Out:
#      Name subname  marks
# 0   sneha      cn     60
# 1  siddha     pds     60
# 2   cheri    math     60
# 3    femi      se     60
# 4   vidhi      cn     59
# 5    diya     pds     59
# 6   sneha    math     59
# 7    haha      se     59

# %%
pd.concat([df2,df1])
# Out:
#      Name subname  marks
# 1   vidhi      cn     59
# 2    diya     pds     59
# 3   sneha    math     59
# 4    haha      se     59
# 1   sneha      cn     60
# 2  siddha     pds     60
# 3   cheri    math     60
# 4    femi      se     60

# %%
pd.concat([df1,df2],keys=["subname"])
# Out:
#              Name subname  marks
# subname 1   sneha      cn     60
#         2  siddha     pds     60
#         3   cheri    math     60
#         4    femi      se     60

# %%
pd.concat([df2,df1],keys=["subname"])
# Out:
#             Name subname  marks
# subname 1  vidhi      cn     59
#         2   diya     pds     59
#         3  sneha    math     59
#         4   haha      se     59

# %%
pd.concat([df1,df2],keys=["subname"],axis=1)
# Out:
#   subname
#      Name subname marks
# 1   sneha      cn    60
# 2  siddha     pds    60
# 3   cheri    math    60
# 4    femi      se    60

# %%
pd.concat([df1,df2],keys=["subname"],axis=0)
# Out:
#              Name subname  marks
# subname 1   sneha      cn     60
#         2  siddha     pds     60
#         3   cheri    math     60
#         4    femi      se     60

# %%
pd.concat([df1,df2],keys=["Name","subname"])
# Out:
#              Name subname  marks
# Name    1   sneha      cn     60
#         2  siddha     pds     60
#         3   cheri    math     60
#         4    femi      se     60
# subname 1   vidhi      cn     59
#         2    diya     pds     59
#         3   sneha    math     59
#         4    haha      se     59

# %%
#concat one DataFrame and one Series
import pandas as pd 
df=pd.DataFrame({
    'A':['A1','A2','A3','A4'],
    'B':['B1','B2','B3','B4']
})
df
# Out:
#     A   B
# 0  A1  B1
# 1  A2  B2
# 2  A3  B3
# 3  A4  B4

# %%
s1=pd.Series(["H","I"])
s1
# Out:
# 0    H
# 1    I
# dtype: object

# %%
pd.concat([df,s1],axis=0)
# Out:
#      A    B    0
# 0   A1   B1  NaN
# 1   A2   B2  NaN
# 2   A3   B3  NaN
# 3   A4   B4  NaN
# 0  NaN  NaN    H
# 1  NaN  NaN    I

# %%
pd.concat([df,s1],axis=1)
# Out:
#     A   B    0
# 0  A1  B1    H
# 1  A2  B2    I
# 2  A3  B3  NaN
# 3  A4  B4  NaN

# %%
pd.concat([df,s1],axis=0,join='inner')
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 0, 1]

# %%
pd.concat([df,s1],axis=1,join='inner')
# Out:
#     A   B  0
# 0  A1  B1  H
# 1  A2  B2  I

# %%
#concate using append
s1=pd.Series([4,5,2])
s2=pd.Series([7,9,8])

s1.append(s2)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_102424\374153408.py:5: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s1.append(s2)
# 0    4
# 1    5
# 2    2
# 0    7
# 1    9
# 2    8
# dtype: int64

# %%
df1.append(df2)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_102424\3062608662.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append(df2)
#      Name subname  marks
# 1   sneha      cn     60
# 2  siddha     pds     60
# 3   cheri    math     60
# 4    femi      se     60
# 1   vidhi      cn     59
# 2    diya     pds     59
# 3   sneha    math     59
# 4    haha      se     59

# %%
df1.append(df2,ignore_index=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_102424\2717680053.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append(df2,ignore_index=True)
#      Name subname  marks
# 0   sneha      cn     60
# 1  siddha     pds     60
# 2   cheri    math     60
# 3    femi      se     60
# 4   vidhi      cn     59
# 5    diya     pds     59
# 6   sneha    math     59
# 7    haha      se     59

# %%
df2.append(df1)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_102424\2914556596.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2.append(df1)
#      Name subname  marks
# 1   vidhi      cn     59
# 2    diya     pds     59
# 3   sneha    math     59
# 4    haha      se     59
# 1   sneha      cn     60
# 2  siddha     pds     60
# 3   cheri    math     60
# 4    femi      se     60

# %%
#transformation of data
import pandas as pd
df=pd.DataFrame({
    'A':[3,5,8,7],
    'B':[7,8,2,5],
    'C':[5,5,4,7]
})
df
# Out:
#    A  B  C
# 0  3  7  5
# 1  5  8  5
# 2  8  2  4
# 3  7  5  7

# %%
result=df.transform(func=lambda x:x+10)
result
# Out:
#     A   B   C
# 0  13  17  15
# 1  15  18  15
# 2  18  12  14
# 3  17  15  17

# %%
result=df.transform(func=['sqrt', lambda x:x*x ,'exp'])
result
# Out:
#           A                               B                               C  \
#        sqrt <lambda>          exp      sqrt <lambda>          exp      sqrt
# 0  1.732051        9    20.085537  2.645751       49  1096.633158  2.236068
# 1  2.236068       25   148.413159  2.828427       64  2980.957987  2.236068
# 2  2.828427       64  2980.957987  1.414214        4     7.389056  2.000000
# 3  2.645751       49  1096.633158  2.236068       25   148.413159  2.645751
#
#
#   <lambda>          exp
# 0       25   148.413159
# 1       25   148.413159
# 2       16    54.598150
# 3       49  1096.633158

# %%
#data aggregation
import pandas as pd
df=pd.read_csv("weather_1.csv")
df
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 6    6:51 AM          28.9        26.1        89                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# ...

# %%
df.columns=[column.replace(" ","_") for column in df.columns]
df
# Out:
#      TimeEST  TemperatureF  Dew_PointF  Humidity  Sea_Level_PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 6    6:51 AM          28.9        26.1        89                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# ...

# %%
df=pd.read_csv("weather_1.csv",usecols=["TemperatureF"])
df
# Out:
#     TemperatureF
# 0           30.9
# 1           30.0
# 2           28.9
# 3           33.1
# 4           30.9
# 5           32.0
# 6           28.9
# 7           33.1
# 8           37.9
# 9           41.0
# 10          46.0
# 11          46.9
# 12          53.1
# 13          55.0
# 14          57.0
# 15          55.9
# 16          57.0
# 17          55.9
# 18          54.0
# 19          52.0
# 20          51.1
# 21          48.0
# 22          46.9
# 23          46.0

# %%
ag=df.aggregate(["min","max","sum"])
ag
# Out:
#      TemperatureF
# min          28.9
# max          57.0
# sum        1051.5

# %%
df=pd.read_csv("weather_1.csv",usecols=["TemperatureF","Humidity"])
df
ag=df.aggregate({'TemperatureF':["min","max","sum"],
                 'Humidity':["min","max","mean"]})
ag
# Out:
#       TemperatureF  Humidity
# min           28.9    50.000
# max           57.0    89.000
# sum         1051.5       NaN
# mean           NaN    71.625

# %%
df
# Out:
#     TemperatureF  Humidity
# 0           30.9        85
# 1           30.0        85
# 2           28.9        85
# 3           33.1        75
# 4           30.9        82
# 5           32.0        79
# 6           28.9        89
# 7           33.1        82
# 8           37.9        73
# 9           41.0        70
# 10          46.0        56
# 11          46.9        52
# 12          53.1        50
# 13          55.0        55
# 14          57.0        55
# 15          55.9        57
# 16          57.0        59
# 17          55.9        64
# 18          54.0        69
# 19          52.0        74
# 20          51.1        77
# 21          48.0        80
# 22          46.9        83
# 23          46.0        83

# %%
ag=df.aggregate(["min","max","sum"],axis=0)
ag
# Out:
#      TemperatureF  Humidity
# min          28.9        50
# max          57.0        89
# sum        1051.5      1719

# %%
ag=df.aggregate(["min","max","sum"],axis=1)
ag
# Out:
#      min   max    sum
# 0   30.9  85.0  115.9
# 1   30.0  85.0  115.0
# 2   28.9  85.0  113.9
# 3   33.1  75.0  108.1
# 4   30.9  82.0  112.9
# 5   32.0  79.0  111.0
# 6   28.9  89.0  117.9
# 7   33.1  82.0  115.1
# 8   37.9  73.0  110.9
# 9   41.0  70.0  111.0
# 10  46.0  56.0  102.0
# 11  46.9  52.0   98.9
# 12  50.0  53.1  103.1
# 13  55.0  55.0  110.0
# 14  55.0  57.0  112.0
# 15  55.9  57.0  112.9
# 16  57.0  59.0  116.0
# 17  55.9  64.0  119.9
# 18  54.0  69.0  123.0
# 19  52.0  74.0  126.0
# 20  51.1  77.0  128.1
# 21  48.0  80.0  128.0
# 22  46.9  83.0  129.9
# 23  46.0  83.0  129.0

# %%
#groupby
import pandas as pd
df=pd.read_csv("weather_1.csv")
df
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 6    6:51 AM          28.9        26.1        89                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# ...

# %%
df.columns=[column.replace(" ","_") for column in df.columns]
df
# Out:
#      TimeEST  TemperatureF  Dew_PointF  Humidity  Sea_Level_PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 6    6:51 AM          28.9        26.1        89                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# ...

# %%
df.groupby(["Wind_Direction"]).sum()
# Out:
#                 TemperatureF  Dew_PointF  Humidity  Sea_Level_PressureIn  \
# Wind_Direction
# Calm                   149.6       130.3       426                151.66
# ESE                     33.1        26.1        75                 30.31
# SE                      73.0        58.1       149                 60.63
# SSW                    443.7       332.1       567                271.51
# SW                     299.0       252.4       452                180.23
# South                   53.1        35.1        50                 30.19
#
#                 VisibilityMPH  PrecipitationIn  Events  WindDirDegrees
# Wind_Direction
# Calm                       50              0.0     0.0               0
# ESE                        10              0.0     0.0             120
# SE                         20              0.0     0.0             270
# SSW                        90              0.0     0.0            1850
# ...

# %%
df.groupby(["Wind_Direction","Wind_SpeedMPH"]).sum()
# Out:
#                               TemperatureF  Dew_PointF  Humidity  \
# Wind_Direction Wind_SpeedMPH
# Calm           Calm                  149.6       130.3       426
# ESE            5.8                    33.1        26.1        75
# SE             4.6                    32.0        26.1        79
#                5.8                    41.0        32.0        70
# SSW            10.4                   46.9        30.0        52
#                11.5                   55.9        41.0        57
#                12.7                   57.0        41.0        55
#                13.8                   57.0        43.0        59
#                15                     54.0        44.1        69
#                16.1                   55.9        44.1        64
#                4.6                    71.0        58.0       155
#                5.8                    46.0        30.9        56
# SW             10.4                   51.1        44.1        77
# ...

# %%
#categorycal data
#limited value, fixed value,number of possible value
#example: gender,blood type

#creating categorical variable
#using series method
import pandas as pd
s=pd.Series(["red","green","blue"],
           dtype="category")
s
# Out:
# 0      red
# 1    green
# 2     blue
# dtype: category
# Categories (3, object): ['blue', 'green', 'red']

# %%
#using pandas category constroctor
import pandas as pd
cat=pd.Categorical(values=["yello","red","blue","orange"],
                  categories=["yello","red","blue"])
cat
# Out:
# ['yello', 'red', 'blue', NaN]
# Categories (3, object): ['yello', 'red', 'blue']

# %%
cat=pd.Categorical(values=["yello","red","blue"],
                  categories=["yello","red","blue","orange",1])
cat
# Out:
# ['yello', 'red', 'blue']
# Categories (5, object): ['yello', 'red', 'blue', 'orange', 1]

# %%
#renaming levels in category
import pandas as pd
s=pd.Series(["red","blue","green"],dtype="category")
cat_data=pd.Series(pd.Categorical(["yello","blue","red","green","black"],categories=s))
cat_data
# Out:
# 0      NaN
# 1     blue
# 2      red
# 3    green
# 4      NaN
# dtype: category
# Categories (3, object): ['blue', 'green', 'red']

# %%
s.cat.categories=["red","yello","pink"]
cat_data=pd.Series(pd.Categorical(["yello","blue","red","green","black"],categories=s))
cat_data
# Out:
# 0    yello
# 1      NaN
# 2      red
# 3      NaN
# 4      NaN
# dtype: category
# Categories (3, object): ['red', 'yello', 'pink']

# %%
import pandas as pd
a=int(input("enter number of students:"))
dept=[]
for i in range(0,a):
    dept.append(input('dept:'))
s=pd.Categorical(dept,["ce","it","ict"])
print(s)
# Out:
# enter number of students:3
# dept:ce
# dept:ce
# dept:it
# ['ce', 'ce', 'it']
# Categories (3, object): ['ce', 'it', 'ict']

# %%
#checking missing value
#isnull(),notnull()
import pandas as pd
d={'A':[1,2,None,4],
   'B':[5,6,7,None],
   'C':[None,8,9,10]
}
df=pd.DataFrame(d)
df
# Out:
#      A    B     C
# 0  1.0  5.0   NaN
# 1  2.0  6.0   8.0
# 2  NaN  7.0   9.0
# 3  4.0  NaN  10.0

# %%
df.isnull()
# Out:
#        A      B      C
# 0  False  False   True
# 1  False  False  False
# 2   True  False  False
# 3  False   True  False

# %%
df.notnull()
# Out:
#        A      B      C
# 0   True   True  False
# 1   True   True   True
# 2  False   True   True
# 3   True  False   True

# %%
#dropping missing value using dropna()
import pandas as pd
d={'A':[1,2,None,4],
   'B':[5,6,7,None],
   'C':[None,8,9,10]}
df=pd.DataFrame(d)
df
# Out:
#      A    B     C
# 0  1.0  5.0   NaN
# 1  2.0  6.0   8.0
# 2  NaN  7.0   9.0
# 3  4.0  NaN  10.0

# %%
df.dropna(axis=0,how="any",inplace=True)
df
# Out:
#      A    B    C
# 1  2.0  6.0  8.0

# %%
import pandas as pd
d={'A':[1,2,None,4],
   'B':[5,6,7,None],
   'C':[None,8,9,10]}
df=pd.DataFrame(d)
df
# Out:
#      A    B     C
# 0  1.0  5.0   NaN
# 1  2.0  6.0   8.0
# 2  NaN  7.0   9.0
# 3  4.0  NaN  10.0

# %%
df.dropna(axis=1,how="any",inplace=True)
df
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
import pandas as pd
d={'A':[1,2,None,4],
   'B':[5,6,7,None],
   'C':[None,8,9,10]}
df=pd.DataFrame(d)
df.dropna(axis=0,how="all",inplace=True)

# %%
import pandas as pd
d={'A':[1,2,2,None,4],
   'B':[5,6,7,2,None],
   'C':[8,9,1,None,9]}
df=pd.DataFrame(d)
print(df)
print("\n")
# Out:
#      A    B    C
# 0  1.0  5.0  8.0
# 1  2.0  6.0  9.0
# 2  2.0  7.0  1.0
# 3  NaN  2.0  NaN
# 4  4.0  NaN  9.0

# %%
newdf=df.dropna(axis=0,how="any")
newdf
# Out:
#      A    B    C
# 0  1.0  5.0  8.0
# 1  2.0  6.0  9.0
# 2  2.0  7.0  1.0

# %%
print("old df length:",len(df))
print("new length:",len(newdf))
print("values at least one none value:",len(df)-len(newdf))
# Out:
# old df length: 5
# new length: 3
# values at least one none value: 2

# %%
df
# Out:
#      A    B    C
# 0  1.0  5.0  8.0
# 1  2.0  6.0  9.0
# 2  2.0  7.0  1.0
# 3  NaN  2.0  NaN
# 4  4.0  NaN  9.0

# %%
newdf=df.dropna(axis=1,how="any")
newdf
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df
# Out:
#      A    B    C
# 0  1.0  5.0  8.0
# 1  2.0  6.0  9.0
# 2  2.0  7.0  1.0
# 3  NaN  2.0  NaN
# 4  4.0  NaN  9.0

# %%
newdf=df.dropna(axis=0,how="any")
newdf
# Out:
#      A    B    C
# 0  1.0  5.0  8.0
# 1  2.0  6.0  9.0
# 2  2.0  7.0  1.0

# %%
#inputing missing data by replace() function
import pandas as pd
s=pd.Series([0,2,4,0,8])
s.replace(0,6)
# Out:
# 0    6
# 1    2
# 2    4
# 3    6
# 4    8
# dtype: int64

# %%
df=pd.DataFrame({'A':[1,2,3,4,5],
                'B':[5,6,7,0,8],
                'C':[0,4,8,9,0]})
df.replace(0,5)
# Out:
#    A  B  C
# 0  1  5  5
# 1  2  6  4
# 2  3  7  8
# 3  4  5  9
# 4  5  8  5

# %%
df.replace(to_replace=[1,2,3,4],value=13)
# Out:
#     A  B   C
# 0  13  5   0
# 1  13  6  13
# 2  13  7   8
# 3  13  0   9
# 4   5  8   0

# %%
df.replace(to_replace=[1,2,3,4],value=[50,2,20,45])
# Out:
#     A  B   C
# 0  50  5   0
# 1   2  6  45
# 2  20  7   8
# 3  45  0   9
# 4   5  8   0

# %%
df.replace({0:1,1:21})
# Out:
#     A  B  C
# 0  21  5  1
# 1   2  6  4
# 2   3  7  8
# 3   4  1  9
# 4   5  8  1

# %%
df.replace({'A':[2,5],'B':6},40)
# Out:
#     A   B  C
# 0   1   5  0
# 1  40  40  4
# 2   3   7  8
# 3   4   0  9
# 4  40   8  0

# %%
s=pd.Series([100,520,50,56,45,12,78])
s.replace([100,520,50],method='pad')
# Out:
# 0    100
# 1    100
# 2    100
# 3     56
# 4     45
# 5     12
# 6     78
# dtype: int64

# %%
s=pd.Series([100,520,50,56,45,12,78])
s.replace([56,45,12],method='pad')
# Out:
# 0    100
# 1    520
# 2     50
# 3     50
# 4     50
# 5     50
# 6     78
# dtype: int64

# %%
s=pd.Series([100,520,50,56,45,12,78])
s.replace([100,520,50],method='pad',limit=2)
# Out:
# 0    100
# 1    100
# 2     50
# 3     56
# 4     45
# 5     12
# 6     78
# dtype: int64

# %%
s=pd.Series([100,520,50,56,45,12,78])
s.replace([50,20],method='ffill')
# Out:
# 0    100
# 1    520
# 2    520
# 3     56
# 4     45
# 5     12
# 6     78
# dtype: int64

# %%
s=pd.Series([100,520,50,56,45,12,78])
s.replace([50,20],method='bfill')
# Out:
# 0    100
# 1    520
# 2     56
# 3     56
# 4     45
# 5     12
# 6     78
# dtype: int64

# %%
import pandas as pd
df=pd.read_csv("weather_1.csv")
df
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 6    6:51 AM          28.9        26.1        89                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# ...

# %%
df.replace(to_replace="Partly Cloudy",value="Cloudy",inplace=True)
df
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 6    6:51 AM          28.9        26.1        89                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# ...

# %%
df
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 6    6:51 AM          28.9        26.1        89                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# ...

# %%
import math as n
import pandas as pd
df=pd.DataFrame({'x':[None,'abc','def'],
                'y':['xy','pq','ij']})
df
# Out:
#       x   y
# 0  None  xy
# 1   abc  pq
# 2   def  ij

# %%
df.replace(n.nan,value=1)
# Out:
#      x   y
# 0    1  xy
# 1  abc  pq
# 2  def  ij

# %%
#interpolate function
#method=linear
#limit direction= forward/backward
#axis=0,1
#limit=1,2,3

import pandas as pd
df=pd.DataFrame({'A':[12,None,10,None,2],
                 'B':[1,2,None,None,None],
                 'c':[20,16,2,3,8],
                 'D':[14,13,2,None,10]})
df
# Out:
#       A    B   c     D
# 0  12.0  1.0  20  14.0
# 1   NaN  2.0  16  13.0
# 2  10.0  NaN   2   2.0
# 3   NaN  NaN   3   NaN
# 4   2.0  NaN   8  10.0

# %%
df.interpolate(method='linear',limitdirection='forward',axis=0)
# Out:
#       A    B   c     D
# 0  12.0  1.0  20  14.0
# 1  11.0  2.0  16  13.0
# 2  10.0  2.0   2   2.0
# 3   6.0  2.0   3   6.0
# 4   2.0  2.0   8  10.0

# %%
#SAMPLING -> random data
# df.sample(n=None,frac=None,axis=None)
import pandas as pd
df=pd.read_csv("weather_1.csv")
row1=df.sample(n=1)
row1
# Out:
#    TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 7  7:51 AM          33.1        28.0        82                 30.34
#
#    VisibilityMPH Wind Direction Wind SpeedMPH Gust SpeedMPH  PrecipitationIn  \
# 7             10            SSW           4.6             -              NaN
#
#    Events     Conditions  WindDirDegrees           DateUTC
# 7     NaN  Mostly Cloudy             200  21-02-2012 12:51

# %%
row1=df.sample(n=1)
row1
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 22  10:51 PM          46.9        42.1        83                 30.01
#
#     VisibilityMPH Wind Direction Wind SpeedMPH Gust SpeedMPH  PrecipitationIn  \
# 22             10             SW           6.9             -              NaN
#
#     Events     Conditions  WindDirDegrees           DateUTC
# 22     NaN  Partly Cloudy             230  22-02-2012 03:51

# %%
row1=df.sample(frac=.25)

# %%
row1
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 23  11:51 PM          46.0        41.0        83                 30.00
# 15   3:51 PM          55.9        41.0        57                 30.08
# 20   8:51 PM          51.1        44.1        77                 30.02
# 10  10:51 AM          46.0        30.9        56                 30.30
# 21   9:51 PM          48.0        42.1        80                 30.02
# 5    5:51 AM          32.0        26.1        79                 30.30
#
#     VisibilityMPH Wind Direction Wind SpeedMPH Gust SpeedMPH  PrecipitationIn  \
# 23             10             SW           5.8             -              NaN
# 15             10            SSW          11.5             -              NaN
# 20             10             SW          10.4             -              NaN
# 10             10            SSW           5.8             -              NaN
# 21             10             SW           5.8             -              NaN
# ...

# %%
row1=df.sample(frac=.50)

# %%
row1
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 12  12:51 PM          53.1        35.1        50                 30.19
# 20   8:51 PM          51.1        44.1        77                 30.02
# 15   3:51 PM          55.9        41.0        57                 30.08
# 8    8:51 AM          37.9        30.0        73                 30.34
# 17   5:51 PM          55.9        44.1        64                 30.02
# 16   4:51 PM          57.0        43.0        59                 30.04
# 9    9:51 AM          41.0        32.0        70                 30.33
# 1    1:51 AM          30.0        26.1        85                 30.35
# 18   6:51 PM          54.0        44.1        69                 30.01
# 10  10:51 AM          46.0        30.9        56                 30.30
#
# ...

# %%
row1=df.sample(frac=.50,axis=1)
row1
# Out:
#     PrecipitationIn  Dew PointF Wind SpeedMPH        Conditions  Humidity  \
# 0               NaN        27.0          Calm     Partly Cloudy        85
# 1               NaN        26.1          Calm     Partly Cloudy        85
# 2               NaN        25.0          Calm  Scattered Clouds        85
# 3               NaN        26.1           5.8  Scattered Clouds        75
# 4               NaN        26.1          Calm  Scattered Clouds        82
# 5               NaN        26.1           4.6  Scattered Clouds        79
# 6               NaN        26.1          Calm     Mostly Cloudy        89
# 7               NaN        28.0           4.6     Mostly Cloudy        82
# 8               NaN        30.0           4.6     Mostly Cloudy        73
# 9               NaN        32.0           5.8     Mostly Cloudy        70
# 10              NaN        30.9           5.8     Mostly Cloudy        56
# 11              NaN        30.0          10.4     Mostly Cloudy        52
# ...

# %%
#find duplicates om dataframe
import pandas as pd
df=pd.read_csv("weather_1.csv")
df
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 6    6:51 AM          28.9        26.1        89                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# ...

# %%
duplicate=df[df.duplicated()]
duplicate
#return something if whole row is duplicate-exists
# Out:
# Empty DataFrame
# Columns: [TimeEST, TemperatureF, Dew PointF, Humidity, Sea Level PressureIn, VisibilityMPH, Wind Direction, Wind SpeedMPH, Gust SpeedMPH, PrecipitationIn, Events, Conditions, WindDirDegrees, DateUTC]
# Index: []

# %%
duplicate=df[df.duplicated('Conditions')]
duplicate
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 1    1:51 AM          30.0        26.1        85                 30.35
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# 12  12:51 PM          53.1        35.1        50                 30.19
# 13   1:51 PM          55.0        39.0        55                 30.15
# 14   2:51 PM          57.0        41.0        55                 30.11
# ...

# %%
df.columns=(column.replace(" ","_") for column in df.columns)
df
# Out:
#      TimeEST  TemperatureF  Dew_PointF  Humidity  Sea_Level_PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 6    6:51 AM          28.9        26.1        89                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# ...

# %%
duplicate=df[df.duplicated(['Conditions','Wind_Direction'])]
duplicate
# Out:
#      TimeEST  TemperatureF  Dew_PointF  Humidity  Sea_Level_PressureIn  \
# 1    1:51 AM          30.0        26.1        85                 30.35
# 4    4:51 AM          30.9        26.1        82                 30.32
# 8    8:51 AM          37.9        30.0        73                 30.34
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# 14   2:51 PM          57.0        41.0        55                 30.11
# 15   3:51 PM          55.9        41.0        57                 30.08
# 16   4:51 PM          57.0        43.0        59                 30.04
# 17   5:51 PM          55.9        44.1        64                 30.02
# 18   6:51 PM          54.0        44.1        69                 30.01
# 19   7:51 PM          52.0        44.1        74                 30.03
# 21   9:51 PM          48.0        42.1        80                 30.02
# ...

# %%
#merge
import pandas as pd
df=pd.read_csv("weather_1.csv")
df
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 6    6:51 AM          28.9        26.1        89                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# ...

# %%
#df.merge(df,how='inner',on=None,left_on=None,right_on=None)

#matching keys in both df
df1=pd.DataFrame({'lkey':['A','B','C','A'],
                 'value':[1,2,3,5]})
df1
# Out:
#   lkey  value
# 0    A      1
# 1    B      2
# 2    C      3
# 3    A      5

# %%
df2=pd.DataFrame({'rkey':['A','A','B','C'],
                 'value':[5,6,7,8]})
df2
# Out:
#   rkey  value
# 0    A      5
# 1    A      6
# 2    B      7
# 3    C      8

# %%
df1.merge(df2,left_on='lkey',right_on='rkey')
# Out:
#   lkey  value_x rkey  value_y
# 0    A        1    A        5
# 1    A        1    A        6
# 2    A        5    A        5
# 3    A        5    A        6
# 4    B        2    B        7
# 5    C        3    C        8

# %%
df1=pd.DataFrame({'key':['A','B','C','D','E'],
                 'value':[1,2,3,5,100]})
df1
# Out:
#   key  value
# 0   A      1
# 1   B      2
# 2   C      3
# 3   D      5
# 4   E    100

# %%
df2=pd.DataFrame({'key':['A','A','B','C','E'],
                 'value':[5,6,7,8,500]})
df2
# Out:
#   key  value
# 0   A      5
# 1   A      6
# 2   B      7
# 3   C      8
# 4   E    500

# %%
df1.merge(df2,how='outer',on='key')
# Out:
#   key  value_x  value_y
# 0   A        1      5.0
# 1   A        1      6.0
# 2   B        2      7.0
# 3   C        3      8.0
# 4   D        5      NaN
# 5   E      100    500.0

# %%
df1.merge(df2,how='inner',on='key')
# Out:
#   key  value_x  value_y
# 0   A        1        5
# 1   A        1        6
# 2   B        2        7
# 3   C        3        8
# 4   E      100      500

# %%
df1.merge(df2,how='left',on='key')
# Out:
#   key  value_x  value_y
# 0   A        1      5.0
# 1   A        1      6.0
# 2   B        2      7.0
# 3   C        3      8.0
# 4   D        5      NaN
# 5   E      100    500.0

# %%
df1.merge(df2,how='right',on='key')
# Out:
#   key  value_x  value_y
# 0   A        1        5
# 1   A        1        6
# 2   B        2        7
# 3   C        3        8
# 4   E      100      500

# %%
#join
#df.join(df2,on=None,how='left/right/inner/outer','lsuffix'=None,'rsuffix'=None)

import pandas as pd
df=pd.DataFrame({'key':['K0','K1','K2','K3','K4','K5'],
                 'A':['A0','A1','A2','A3','A4','A5'],
                 'B':['B0','B1','B2','B3','B4','B5']})
df
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3
# 4  K4  A4  B4
# 5  K5  A5  B5

# %%
df2=pd.DataFrame({'key':['K0','K1','K2','K3','K4','K5'],
                 'C':['C0','C1','C2','C3','C4','C5'],})
df2
# Out:
#   key   C
# 0  K0  C0
# 1  K1  C1
# 2  K2  C2
# 3  K3  C3
# 4  K4  C4
# 5  K5  C5

# %%
df.join(df2.set_index('key'),on='key',how='inner')
# Out:
#   key   A   B   C
# 0  K0  A0  B0  C0
# 1  K1  A1  B1  C1
# 2  K2  A2  B2  C2
# 3  K3  A3  B3  C3
# 4  K4  A4  B4  C4
# 5  K5  A5  B5  C5

# %%
df.join(df2.set_index('key'),on='key',how='outer')
# Out:
#   key   A   B   C
# 0  K0  A0  B0  C0
# 1  K1  A1  B1  C1
# 2  K2  A2  B2  C2
# 3  K3  A3  B3  C3
# 4  K4  A4  B4  C4
# 5  K5  A5  B5  C5

# %%
df.join(df2.set_index('key'),on='key',how='left')
# Out:
#   key   A   B   C
# 0  K0  A0  B0  C0
# 1  K1  A1  B1  C1
# 2  K2  A2  B2  C2
# 3  K3  A3  B3  C3
# 4  K4  A4  B4  C4
# 5  K5  A5  B5  C5

# %%
df.join(df2.set_index('key'),on='key',how='right')
# Out:
#   key   A   B   C
# 0  K0  A0  B0  C0
# 1  K1  A1  B1  C1
# 2  K2  A2  B2  C2
# 3  K3  A3  B3  C3
# 4  K4  A4  B4  C4
# 5  K5  A5  B5  C5
