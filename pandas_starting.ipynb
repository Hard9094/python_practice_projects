# %%
#create series
import pandas as pd
s=pd.Series([7,5,4,9,1,80])
s
# Out:
# 0     7
# 1     5
# 2     4
# 3     9
# 4     1
# 5    80
# dtype: int64

# %%
#access the element
print(s[0])
print(s[0]+s[1])
# Out:
# 7
# 12

# %%
import pandas as pd
import numpy as np
i=["name","phone","email","address","website"]
d=["sneha","1234","xyz@gmail.com","street123","www.google.com"]
s=pd.Series(data=d,index=i)
print(s)
# Out:
# name                sneha
# phone                1234
# email       xyz@gmail.com
# address         street123
# website    www.google.com
# dtype: object

# %%
import pandas as pd
d1=pd.DataFrame({'apple':[3,2,0,1],'orange':[0,3,7,8]})
d=pd.DataFrame(d1)
d
# Out:
#    apple  orange
# 0      3       0
# 1      2       3
# 2      0       7
# 3      1       8

# %%
import pandas as pd
p=pd.DataFrame(Date,index=['jun','feb','mar','apr'])
print(p)
p.index=pd.date_range(start="2022-01-01",periods=4)
print(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 p=pd.DataFrame(Date,index=['jun','feb','mar','apr'])
#       3 print(p)
#       4 p.index=pd.date_range(start="2022-01-01",periods=4)
#
# NameError: name 'Date' is not defined

# %%
#adding a new col 
# 1) declaring a list as column
# 2) using DataFrame.insert()

# 1
import pandas as pd
df=pd.read_csv("weather_1.csv")
df
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 6    6:51 AM          28.9        26.1        89                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# ...

# %%
g=("female","male","fe-male","female","male","fe-male","female","male","fe-male","female","male","fe-male","female","male","fe-male","female","male","fe-male","female","male","fe-male","female","male","fe-male")
df["gender"]=g
df
# Out:
#      TimeEST  new  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 0   12:51 AM   10          30.9        27.0        85                 30.35
# 1    1:51 AM   50          30.0        26.1        85                 30.35
# 2    2:51 AM   20          28.9        25.0        85                 30.33
# 3    3:51 AM   10          33.1        26.1        75                 30.31
# 4    4:51 AM   20          30.9        26.1        82                 30.32
# 5    5:51 AM   10          32.0        26.1        79                 30.30
# 6    6:51 AM   20          28.9        26.1        89                 30.31
# 7    7:51 AM   10          33.1        28.0        82                 30.34
# 8    8:51 AM   40          37.9        30.0        73                 30.34
# 9    9:51 AM   50          41.0        32.0        70                 30.33
# 10  10:51 AM   80          46.0        30.9        56                 30.30
# ...

# %%
#2
df.insert(loc=1,column='new',value=[10,50,20,10,20,10,20,10,40,50,80,70,10,50,52,63,42,82,10,12,52,42,44,45])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 df.insert(loc=1,column='new',value=[10,50,20,10,20,10,20,10,40,50,80,70,10,50,52,63,42,82,10,12,52,42,44,45])
#       2 df
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4440, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4434     raise ValueError(
#    4435         "Cannot specify 'allow_duplicates=True' when "
#    4436         "'self.flags.allows_duplicate_labels' is False."
#    4437     )
#    4438 if not allow_duplicates and column in self.columns:
#    4439     # Should this be a different kind of error??
# -> 4440     raise ValueError(f"cannot insert {column}, already exists")
#    4441 if not isinstance(loc, int):
#    4442     raise TypeError("loc must be int")
#
# ValueError: cannot insert new, already exists

# %%
df
# Out:
#      TimeEST  new  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 0   12:51 AM   10          30.9        27.0        85                 30.35
# 1    1:51 AM   50          30.0        26.1        85                 30.35
# 2    2:51 AM   20          28.9        25.0        85                 30.33
# 3    3:51 AM   10          33.1        26.1        75                 30.31
# 4    4:51 AM   20          30.9        26.1        82                 30.32
# 5    5:51 AM   10          32.0        26.1        79                 30.30
# 6    6:51 AM   20          28.9        26.1        89                 30.31
# 7    7:51 AM   10          33.1        28.0        82                 30.34
# 8    8:51 AM   40          37.9        30.0        73                 30.34
# 9    9:51 AM   50          41.0        32.0        70                 30.33
# 10  10:51 AM   80          46.0        30.9        56                 30.30
# ...

# %%
#deleting column
df=df.drop(columns=['new'])

# %%
df
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 6    6:51 AM          28.9        26.1        89                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# ...

# %%
df.drop(columns="gender",inplace=True)
df
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 6    6:51 AM          28.9        26.1        89                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# ...

# %%
#row delete
df.drop([5,6],errors="ignore",inplace=True,axis=0)
df
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# 12  12:51 PM          53.1        35.1        50                 30.19
# 13   1:51 PM          55.0        39.0        55                 30.15
# ...

# %%
df.drop([5,6],errors="ignore",inplace=True,axis=1)
df
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# 12  12:51 PM          53.1        35.1        50                 30.19
# 13   1:51 PM          55.0        39.0        55                 30.15
# ...
