# %%
#get specific column using get
import pandas as pd
df=pd.read_csv("weather_1.csv")
df
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 6    6:51 AM          28.9        26.1        89                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# ...

# %%
print(df.get("TemperatureF"))
# Out:
# 0     30.9
# 1     30.0
# 2     28.9
# 3     33.1
# 4     30.9
# 5     32.0
# 6     28.9
# 7     33.1
# 8     37.9
# 9     41.0
# 10    46.0
# 11    46.9
# 12    53.1
# 13    55.0
# 14    57.0
# 15    55.9
# 16    57.0
# 17    55.9
# 18    54.0
# 19    52.0
# 20    51.1
# 21    48.0
# 22    46.9
# 23    46.0
# Name: TemperatureF, dtype: float64

# %%
print(df.get(["TemperatureF","TimeEST"]))
# Out:
#     TemperatureF   TimeEST
# 0           30.9  12:51 AM
# 1           30.0   1:51 AM
# 2           28.9   2:51 AM
# 3           33.1   3:51 AM
# 4           30.9   4:51 AM
# 5           32.0   5:51 AM
# 6           28.9   6:51 AM
# 7           33.1   7:51 AM
# 8           37.9   8:51 AM
# 9           41.0   9:51 AM
# 10          46.0  10:51 AM
# 11          46.9  11:51 AM
# 12          53.1  12:51 PM
# 13          55.0   1:51 PM
# 14          57.0   2:51 PM
# 15          55.9   3:51 PM
# 16          57.0   4:51 PM
# 17          55.9   5:51 PM
# 18          54.0   6:51 PM
# 19          52.0   7:51 PM
# 20          51.1   8:51 PM
# 21          48.0   9:51 PM
# 22          46.9  10:51 PM
# 23          46.0  11:51 PM

# %%
df
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 6    6:51 AM          28.9        26.1        89                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# ...

# %%
#slicing and dicing
print(df.loc[0])
# Out:
# TimeEST                         12:51 AM
# TemperatureF                        30.9
# Dew PointF                          27.0
# Humidity                              85
# Sea Level PressureIn               30.35
# VisibilityMPH                         10
# Wind Direction                      Calm
# Wind SpeedMPH                       Calm
# Gust SpeedMPH                          -
# PrecipitationIn                      NaN
# Events                               NaN
# Conditions                 Partly Cloudy
# WindDirDegrees                         0
# DateUTC                 21-02-2012 05:51
# Name: 0, dtype: object

# %%
print(df.loc[:,["Humidity"]])
# Out:
#     Humidity
# 0         85
# 1         85
# 2         85
# 3         75
# 4         82
# 5         79
# 6         89
# 7         82
# 8         73
# 9         70
# 10        56
# 11        52
# 12        50
# 13        55
# 14        55
# 15        57
# 16        59
# 17        64
# 18        69
# 19        74
# 20        77
# 21        80
# 22        83
# 23        83

# %%
print(df.loc[[1,5],["Humidity","Sea Level PressureIn"]])
# Out:
#    Humidity  Sea Level PressureIn
# 1        85                 30.35
# 5        79                 30.30

# %%
print(df.iloc[1])
# Out:
# TimeEST                          1:51 AM
# TemperatureF                        30.0
# Dew PointF                          26.1
# Humidity                              85
# Sea Level PressureIn               30.35
# VisibilityMPH                         10
# Wind Direction                      Calm
# Wind SpeedMPH                       Calm
# Gust SpeedMPH                          -
# PrecipitationIn                      NaN
# Events                               NaN
# Conditions                 Partly Cloudy
# WindDirDegrees                         0
# DateUTC                 21-02-2012 06:51
# Name: 1, dtype: object

# %%
print(df.iloc[[1],[0]])
# Out:
#    TimeEST
# 1  1:51 AM

# %%
print(df.iloc[:,[0]])
# Out:
#      TimeEST
# 0   12:51 AM
# 1    1:51 AM
# 2    2:51 AM
# 3    3:51 AM
# 4    4:51 AM
# 5    5:51 AM
# 6    6:51 AM
# 7    7:51 AM
# 8    8:51 AM
# 9    9:51 AM
# 10  10:51 AM
# 11  11:51 AM
# 12  12:51 PM
# 13   1:51 PM
# 14   2:51 PM
# 15   3:51 PM
# 16   4:51 PM
# 17   5:51 PM
# 18   6:51 PM
# 19   7:51 PM
# 20   8:51 PM
# 21   9:51 PM
# 22  10:51 PM
# 23  11:51 PM

# %%
print(df.iloc[0,1])
# Out:
# 30.9

# %%
print(df.iloc[0,4])
# Out:
# 30.35

# %%
print(df.iloc[0:4,4:5])
# Out:
#    Sea Level PressureIn
# 0                 30.35
# 1                 30.35
# 2                 30.33
# 3                 30.31

# %%
print(df)
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 6    6:51 AM          28.9        26.1        89                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# ...

# %%
df
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 6    6:51 AM          28.9        26.1        89                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# ...

# %%
print(df.iloc[[0,2,3],[4,5]])
# Out:
#    Sea Level PressureIn  VisibilityMPH
# 0                 30.35             10
# 2                 30.33             10
# 3                 30.31             10

# %%
#get specific column
import pandas as pd
df1=pd.read_csv("weather_1.csv",skipinitialspace=True)
df1
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 6    6:51 AM          28.9        26.1        89                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# ...

# %%
df2=df1.values.tolist()
df2
# Out:
# [['12:51 AM',
#   30.9,
#   27.0,
#   85,
#   30.35,
#   10,
#   'Calm',
#   'Calm',
#   '-',
#   nan,
#   nan,
#   'Partly Cloudy',
#   0,
#   '21-02-2012 05:51'],
#  ['1:51 AM',
#   30.0,
#   26.1,
#   85,
#   30.35,
#   10,
#   'Calm',
#   'Calm',
#   '-',
#   nan,
#   nan,
#   'Partly Cloudy',
#   0,
#   '21-02-2012 06:51'],
#  ['2:51 AM',
#   28.9,
#   25.0,
#   85,
#   30.33,
#   10,
#   'Calm',
#   'Calm',
#   '-',
#   nan,
#   nan,
#   'Scattered Clouds',
#   0,
#   '21-02-2012 07:51'],
#  ['3:51 AM',
#   33.1,
#   26.1,
#   75,
#   30.31,
#   10,
#   'ESE',
#   '5.8',
#   '-',
#   nan,
#   nan,
#   'Scattered Clouds',
#   120,
#   '21-02-2012 08:51'],
#  ['4:51 AM',
#   30.9,
#   26.1,
#   82,
#   30.32,
#   10,
#   'Calm',
#   'Calm',
#   '-',
#   nan,
#   nan,
#   'Scattered Clouds',
#   0,
#   '21-02-2012 09:51'],
#  ['5:51 AM',
#   32.0,
#   26.1,
#   79,
#   30.3,
#   10,
#   'SE',
#   '4.6',
#   '-',
#   nan,
#   nan,
#   'Scattered Clouds',
#   130,
# ...

# %%
df2=df1["TimeEST"].tolist()
df2
# Out:
# ['12:51 AM',
#  '1:51 AM',
#  '2:51 AM',
#  '3:51 AM',
#  '4:51 AM',
#  '5:51 AM',
#  '6:51 AM',
#  '7:51 AM',
#  '8:51 AM',
#  '9:51 AM',
#  '10:51 AM',
#  '11:51 AM',
#  '12:51 PM',
#  '1:51 PM',
#  '2:51 PM',
#  '3:51 PM',
#  '4:51 PM',
#  '5:51 PM',
#  '6:51 PM',
#  '7:51 PM',
#  '8:51 PM',
#  '9:51 PM',
#  '10:51 PM',
#  '11:51 PM']

# %%
df2=df1["Wind SpeedMPH"].tolist()
df2
# Out:
# ['Calm',
#  'Calm',
#  'Calm',
#  '5.8',
#  'Calm',
#  '4.6',
#  'Calm',
#  '4.6',
#  '4.6',
#  '5.8',
#  '5.8',
#  '10.4',
#  '9.2',
#  '15',
#  '12.7',
#  '11.5',
#  '13.8',
#  '16.1',
#  '15',
#  '8.1',
#  '10.4',
#  '5.8',
#  '6.9',
#  '5.8']

# %%
df2=df1.loc[:,"TimeEST"].tolist()
df2
# Out:
# ['12:51 AM',
#  '1:51 AM',
#  '2:51 AM',
#  '3:51 AM',
#  '4:51 AM',
#  '5:51 AM',
#  '6:51 AM',
#  '7:51 AM',
#  '8:51 AM',
#  '9:51 AM',
#  '10:51 AM',
#  '11:51 AM',
#  '12:51 PM',
#  '1:51 PM',
#  '2:51 PM',
#  '3:51 PM',
#  '4:51 PM',
#  '5:51 PM',
#  '6:51 PM',
#  '7:51 PM',
#  '8:51 PM',
#  '9:51 PM',
#  '10:51 PM',
#  '11:51 PM']

# %%
df2=df1.loc[:,"TimeEST"].tolist()
df2
# Out:
# ['12:51 AM',
#  '1:51 AM',
#  '2:51 AM',
#  '3:51 AM',
#  '4:51 AM',
#  '5:51 AM',
#  '6:51 AM',
#  '7:51 AM',
#  '8:51 AM',
#  '9:51 AM',
#  '10:51 AM',
#  '11:51 AM',
#  '12:51 PM',
#  '1:51 PM',
#  '2:51 PM',
#  '3:51 PM',
#  '4:51 PM',
#  '5:51 PM',
#  '6:51 PM',
#  '7:51 PM',
#  '8:51 PM',
#  '9:51 PM',
#  '10:51 PM',
#  '11:51 PM']

# %%
#sort by index

sdf=df1.sort_index()
sdf
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 6    6:51 AM          28.9        26.1        89                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# ...

# %%
sdf=df1.sort_index(ascending=True)
sdf
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 6    6:51 AM          28.9        26.1        89                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# ...

# %%
sdf=df1.sort_index(axis=1)
sdf
# Out:
#           Conditions           DateUTC  Dew PointF  Events Gust SpeedMPH  \
# 0      Partly Cloudy  21-02-2012 05:51        27.0     NaN             -
# 1      Partly Cloudy  21-02-2012 06:51        26.1     NaN             -
# 2   Scattered Clouds  21-02-2012 07:51        25.0     NaN             -
# 3   Scattered Clouds  21-02-2012 08:51        26.1     NaN             -
# 4   Scattered Clouds  21-02-2012 09:51        26.1     NaN             -
# 5   Scattered Clouds  21-02-2012 10:51        26.1     NaN             -
# 6      Mostly Cloudy  21-02-2012 11:51        26.1     NaN             -
# 7      Mostly Cloudy  21-02-2012 12:51        28.0     NaN             -
# 8      Mostly Cloudy  21-02-2012 13:51        30.0     NaN             -
# 9      Mostly Cloudy  21-02-2012 14:51        32.0     NaN             -
# 10     Mostly Cloudy  21-02-2012 15:51        30.9     NaN             -
# 11     Mostly Cloudy  21-02-2012 16:51        30.0     NaN             -
# ...

# %%
sdf=df1.sort_index(axis=1,ascending=False)
sdf
# Out:
#     WindDirDegrees Wind SpeedMPH Wind Direction  VisibilityMPH   TimeEST  \
# 0                0          Calm           Calm             10  12:51 AM
# 1                0          Calm           Calm             10   1:51 AM
# 2                0          Calm           Calm             10   2:51 AM
# 3              120           5.8            ESE             10   3:51 AM
# 4                0          Calm           Calm             10   4:51 AM
# 5              130           4.6             SE             10   5:51 AM
# 6                0          Calm           Calm             10   6:51 AM
# 7              200           4.6            SSW             10   7:51 AM
# 8              200           4.6            SSW             10   8:51 AM
# 9              140           5.8             SE             10   9:51 AM
# 10             200           5.8            SSW             10  10:51 AM
# 11             210          10.4            SSW             10  11:51 AM
# ...

# %%
#sort by values

df=df1.sort_values(by="TemperatureF")
df
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 2    2:51 AM          28.9        25.0        85                 30.33
# 6    6:51 AM          28.9        26.1        89                 30.31
# 1    1:51 AM          30.0        26.1        85                 30.35
# 0   12:51 AM          30.9        27.0        85                 30.35
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 3    3:51 AM          33.1        26.1        75                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 23  11:51 PM          46.0        41.0        83                 30.00
# 10  10:51 AM          46.0        30.9        56                 30.30
# ...

# %%
df=df1.sort_values("TemperatureF")
df
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 2    2:51 AM          28.9        25.0        85                 30.33
# 6    6:51 AM          28.9        26.1        89                 30.31
# 1    1:51 AM          30.0        26.1        85                 30.35
# 0   12:51 AM          30.9        27.0        85                 30.35
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 3    3:51 AM          33.1        26.1        75                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 23  11:51 PM          46.0        41.0        83                 30.00
# 10  10:51 AM          46.0        30.9        56                 30.30
# ...

# %%
df=df1.sort_values("TemperatureF",ascending=False)
df
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 16   4:51 PM          57.0        43.0        59                 30.04
# 14   2:51 PM          57.0        41.0        55                 30.11
# 17   5:51 PM          55.9        44.1        64                 30.02
# 15   3:51 PM          55.9        41.0        57                 30.08
# 13   1:51 PM          55.0        39.0        55                 30.15
# 18   6:51 PM          54.0        44.1        69                 30.01
# 12  12:51 PM          53.1        35.1        50                 30.19
# 19   7:51 PM          52.0        44.1        74                 30.03
# 20   8:51 PM          51.1        44.1        77                 30.02
# 21   9:51 PM          48.0        42.1        80                 30.02
# 22  10:51 PM          46.9        42.1        83                 30.01
# 11  11:51 AM          46.9        30.0        52                 30.27
# ...

# %%
df=df1.sort_values(by=["TemperatureF","TemperatureF"])
df
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 2    2:51 AM          28.9        25.0        85                 30.33
# 6    6:51 AM          28.9        26.1        89                 30.31
# 1    1:51 AM          30.0        26.1        85                 30.35
# 0   12:51 AM          30.9        27.0        85                 30.35
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 3    3:51 AM          33.1        26.1        75                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 23  11:51 PM          46.0        41.0        83                 30.00
# ...

# %%
#zip(map the value)
name=["ek","do","tin"]
roll_no=[1,2,3]
mapped=zip(name,roll_no)
print(list(mapped))
# Out:
# [('ek', 1), ('do', 2), ('tin', 3)]

# %%
import pandas as pd
df=pd.read_csv("weather_1.csv")
print(list(zip(df["TemperatureF"],df["Humidity"])))
# Out:
# [(30.9, 85), (30.0, 85), (28.9, 85), (33.1, 75), (30.9, 82), (32.0, 79), (28.9, 89), (33.1, 82), (37.9, 73), (41.0, 70), (46.0, 56), (46.9, 52), (53.1, 50), (55.0, 55), (57.0, 55), (55.9, 57), (57.0, 59), (55.9, 64), (54.0, 69), (52.0, 74), (51.1, 77), (48.0, 80), (46.9, 83), (46.0, 83)]

# %%
print(list(zip(*df.values)))
# Out:
# [('12:51 AM', '1:51 AM', '2:51 AM', '3:51 AM', '4:51 AM', '5:51 AM', '6:51 AM', '7:51 AM', '8:51 AM', '9:51 AM', '10:51 AM', '11:51 AM', '12:51 PM', '1:51 PM', '2:51 PM', '3:51 PM', '4:51 PM', '5:51 PM', '6:51 PM', '7:51 PM', '8:51 PM', '9:51 PM', '10:51 PM', '11:51 PM'), (30.9, 30.0, 28.9, 33.1, 30.9, 32.0, 28.9, 33.1, 37.9, 41.0, 46.0, 46.9, 53.1, 55.0, 57.0, 55.9, 57.0, 55.9, 54.0, 52.0, 51.1, 48.0, 46.9, 46.0), (27.0, 26.1, 25.0, 26.1, 26.1, 26.1, 26.1, 28.0, 30.0, 32.0, 30.9, 30.0, 35.1, 39.0, 41.0, 41.0, 43.0, 44.1, 44.1, 44.1, 44.1, 42.1, 42.1, 41.0), (85, 85, 85, 75, 82, 79, 89, 82, 73, 70, 56, 52, 50, 55, 55, 57, 59, 64, 69, 74, 77, 80, 83, 83), (30.35, 30.35, 30.33, 30.31, 30.32, 30.3, 30.31, 30.34, 30.34, 30.33, 30.3, 30.27, 30.19, 30.15, 30.11, 30.08, 30.04, 30.02, 30.01, 30.03, 30.02, 30.02, 30.01, 30.0), (10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10), ('Calm', 'Calm', 'Calm', 'ESE', 'Calm', 'SE', 'Calm', 'SSW', 'SSW', 'S
# ...

# %%
#filtering data
#provide query() method
df=pd.read_csv("weather_1.csv")
df
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 6    6:51 AM          28.9        26.1        89                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# ...

# %%
df.columns=[column.replace(" ","_") for column in df.columns]
df
# Out:
#      TimeEST  TemperatureF  Dew_PointF  Humidity  Sea_Level_PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 6    6:51 AM          28.9        26.1        89                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# ...

# %%
df.query('Dew_PointF==44.1',inplace=True)
df
# Out:
#     TimeEST  TemperatureF  Dew_PointF  Humidity  Sea_Level_PressureIn  \
# 17  5:51 PM          55.9        44.1        64                 30.02
# 18  6:51 PM          54.0        44.1        69                 30.01
# 19  7:51 PM          52.0        44.1        74                 30.03
# 20  8:51 PM          51.1        44.1        77                 30.02
#
#     VisibilityMPH Wind_Direction Wind_SpeedMPH Gust_SpeedMPH  PrecipitationIn  \
# 17             10            SSW          16.1             -              NaN
# 18             10            SSW            15             -              NaN
# 19             10             SW           8.1             -              NaN
# 20             10             SW          10.4             -              NaN
#
#     Events     Conditions  WindDirDegrees           DateUTC
# 17     NaN  Mostly Cloudy             210  21-02-2012 22:51
# 18     NaN  Mostly Cloudy             210  21-02-2012 23:51
# ...

# %%
df.query('Wind_Direction=="SSW" and VisibilityMPH > 8.1',inplace=True)
df
# Out:
#     TimeEST  TemperatureF  Dew_PointF  Humidity  Sea_Level_PressureIn  \
# 17  5:51 PM          55.9        44.1        64                 30.02
# 18  6:51 PM          54.0        44.1        69                 30.01
#
#     VisibilityMPH Wind_Direction Wind_SpeedMPH Gust_SpeedMPH  PrecipitationIn  \
# 17             10            SSW          16.1             -              NaN
# 18             10            SSW            15             -              NaN
#
#     Events     Conditions  WindDirDegrees           DateUTC
# 17     NaN  Mostly Cloudy             210  21-02-2012 22:51
# 18     NaN  Mostly Cloudy             210  21-02-2012 23:51

# %%
df=pd.read_csv("weather_1.csv")
df
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 2    2:51 AM          28.9        25.0        85                 30.33
# 3    3:51 AM          33.1        26.1        75                 30.31
# 4    4:51 AM          30.9        26.1        82                 30.32
# 5    5:51 AM          32.0        26.1        79                 30.30
# 6    6:51 AM          28.9        26.1        89                 30.31
# 7    7:51 AM          33.1        28.0        82                 30.34
# 8    8:51 AM          37.9        30.0        73                 30.34
# 9    9:51 AM          41.0        32.0        70                 30.33
# 10  10:51 AM          46.0        30.9        56                 30.30
# 11  11:51 AM          46.9        30.0        52                 30.27
# ...

# %%
df.loc[df["Conditions"].str.contains("Clear")]
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 23  11:51 PM          46.0        41.0        83                  30.0
#
#     VisibilityMPH Wind Direction Wind SpeedMPH Gust SpeedMPH  PrecipitationIn  \
# 23             10             SW           5.8             -              NaN
#
#     Events Conditions  WindDirDegrees           DateUTC
# 23     NaN      Clear             230  22-02-2012 04:51

# %%
df.loc[df["Conditions"].str.startswith("P")]
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 0   12:51 AM          30.9        27.0        85                 30.35
# 1    1:51 AM          30.0        26.1        85                 30.35
# 20   8:51 PM          51.1        44.1        77                 30.02
# 21   9:51 PM          48.0        42.1        80                 30.02
# 22  10:51 PM          46.9        42.1        83                 30.01
#
#     VisibilityMPH Wind Direction Wind SpeedMPH Gust SpeedMPH  PrecipitationIn  \
# 0              10           Calm          Calm             -              NaN
# 1              10           Calm          Calm             -              NaN
# 20             10             SW          10.4             -              NaN
# 21             10             SW           5.8             -              NaN
# 22             10             SW           6.9             -              NaN
#
#     Events     Conditions  WindDirDegrees           DateUTC
# ...

# %%
df.loc[df["Conditions"].str.endswith("r")]
# Out:
#      TimeEST  TemperatureF  Dew PointF  Humidity  Sea Level PressureIn  \
# 23  11:51 PM          46.0        41.0        83                  30.0
#
#     VisibilityMPH Wind Direction Wind SpeedMPH Gust SpeedMPH  PrecipitationIn  \
# 23             10             SW           5.8             -              NaN
#
#     Events Conditions  WindDirDegrees           DateUTC
# 23     NaN      Clear             230  22-02-2012 04:51

# %%
#excelfile operation
import pandas as pd
df=pd.read_excel("Aug_2022.xlsx")
df
# Out:
#     Days  Time  Max T  Min T  Dry T  Wet T  Hum   Press Wind D.  Wind St  \
# 0      1     9  26.43  11.78  18.97  16.22   76  1023.9       S        1
# 1      2     9  26.18  18.20  21.54  19.38   82  1016.7      SW        2
# 2      3     9  26.45  17.86  20.23  18.59   85  1016.0     WNW        2
# 3      4     9  21.70  12.89  18.31  15.38   74  1020.0      NW        3
# 4      5     9  20.79  10.02  15.38  13.45   81  1027.4      NW        3
# 5      6     9  23.54   7.32  17.81  15.06   75  1034.9     NNW        2
# 6      7     9  25.51   9.02  12.29  10.72   83  1031.9      NW        2
# 7      8     9  28.49  11.47  20.51  17.57   75  1032.9     NNE        1
# 8      9     9  29.43  12.41  19.03  16.16   78  1034.6       N        1
# 9     10     9  31.57  13.27  24.25  20.95   74  1030.9       S        1
# 10    11     9  33.09  13.30  24.20  20.56   71  1027.9       E        1
# 11    12     9  33.25  14.10  26.49  23.76   80  1024.9      NE        2
# ...

# %%
df.columns=[column.replace(" ","_") for column in df.columns]
df
# Out:
#     Days  Time  Max_T  Min_T  Dry_T  Wet_T  Hum   Press Wind_D.  Wind_St  \
# 0      1     9  26.43  11.78  18.97  16.22   76  1023.9       S        1
# 1      2     9  26.18  18.20  21.54  19.38   82  1016.7      SW        2
# 2      3     9  26.45  17.86  20.23  18.59   85  1016.0     WNW        2
# 3      4     9  21.70  12.89  18.31  15.38   74  1020.0      NW        3
# 4      5     9  20.79  10.02  15.38  13.45   81  1027.4      NW        3
# 5      6     9  23.54   7.32  17.81  15.06   75  1034.9     NNW        2
# 6      7     9  25.51   9.02  12.29  10.72   83  1031.9      NW        2
# 7      8     9  28.49  11.47  20.51  17.57   75  1032.9     NNE        1
# 8      9     9  29.43  12.41  19.03  16.16   78  1034.6       N        1
# 9     10     9  31.57  13.27  24.25  20.95   74  1030.9       S        1
# 10    11     9  33.09  13.30  24.20  20.56   71  1027.9       E        1
# 11    12     9  33.25  14.10  26.49  23.76   80  1024.9      NE        2
# ...

# %%
df.loc[df["Max_T"]>30.0]
# Out:
#     Days  Time  Max_T  Min_T  Dry_T  Wet_T  Hum   Press Wind_D.  Wind_St  \
# 9     10     9  31.57  13.27  24.25  20.95   74  1030.9       S        1
# 10    11     9  33.09  13.30  24.20  20.56   71  1027.9       E        1
# 11    12     9  33.25  14.10  26.49  23.76   80  1024.9      NE        2
# 12    13     9  33.23  15.27  22.48  19.72   77  1021.2      NE        2
# 13    14     9  33.30  15.98  24.40  21.28   76  1013.2      NE        1
#
#     Cl_am Cl_Ty  Rain  Snow
# 9       0    C.   0.0     0
# 10      0    C.   0.0     0
# 11      0    C.   0.0     0
# 12      0    C.   0.0     0
# 13      1   As.   0.0     0

# %%
df
# Out:
#     Days  Time  Max_T  Min_T  Dry_T  Wet_T  Hum   Press Wind_D.  Wind_St  \
# 0      1     9  26.43  11.78  18.97  16.22   76  1023.9       S        1
# 1      2     9  26.18  18.20  21.54  19.38   82  1016.7      SW        2
# 2      3     9  26.45  17.86  20.23  18.59   85  1016.0     WNW        2
# 3      4     9  21.70  12.89  18.31  15.38   74  1020.0      NW        3
# 4      5     9  20.79  10.02  15.38  13.45   81  1027.4      NW        3
# 5      6     9  23.54   7.32  17.81  15.06   75  1034.9     NNW        2
# 6      7     9  25.51   9.02  12.29  10.72   83  1031.9      NW        2
# 7      8     9  28.49  11.47  20.51  17.57   75  1032.9     NNE        1
# 8      9     9  29.43  12.41  19.03  16.16   78  1034.6       N        1
# 9     10     9  31.57  13.27  24.25  20.95   74  1030.9       S        1
# 10    11     9  33.09  13.30  24.20  20.56   71  1027.9       E        1
# 11    12     9  33.25  14.10  26.49  23.76   80  1024.9      NE        2
# ...

# %%
df.query('Dry_T>20.51 and Hum>75',inplace=True)
df
# Out:
#     Days  Time  Max_T  Min_T  Dry_T  Wet_T  Hum   Press Wind_D.  Wind_St  \
# 1      2     9  26.18  18.20  21.54  19.38   82  1016.7      SW        2
# 11    12     9  33.25  14.10  26.49  23.76   80  1024.9      NE        2
# 12    13     9  33.23  15.27  22.48  19.72   77  1021.2      NE        2
# 13    14     9  33.30  15.98  24.40  21.28   76  1013.2      NE        1
# 14    15     9  26.31  16.16  21.44  18.67   77  1006.6      NW        2
# 23    24     9  24.39  19.31  20.79  18.45   80  1019.7      SW        2
#
#     Cl_am Cl_Ty  Rain  Snow
# 1       8   Sc.   0.4     0
# 11      0    C.   0.0     0
# 12      0    C.   0.0     0
# 13      1   As.   0.0     0
# 14      6   Sc.   0.0     0
# 23      8   Cc.   5.0     0

# %%
import pandas as pd
df=pd.read_excel("Aug_2022.xlsx")
df
# Out:
#     Days  Time  Max T  Min T  Dry T  Wet T  Hum   Press Wind D.  Wind St  \
# 0      1     9  26.43  11.78  18.97  16.22   76  1023.9       S        1
# 1      2     9  26.18  18.20  21.54  19.38   82  1016.7      SW        2
# 2      3     9  26.45  17.86  20.23  18.59   85  1016.0     WNW        2
# 3      4     9  21.70  12.89  18.31  15.38   74  1020.0      NW        3
# 4      5     9  20.79  10.02  15.38  13.45   81  1027.4      NW        3
# 5      6     9  23.54   7.32  17.81  15.06   75  1034.9     NNW        2
# 6      7     9  25.51   9.02  12.29  10.72   83  1031.9      NW        2
# 7      8     9  28.49  11.47  20.51  17.57   75  1032.9     NNE        1
# 8      9     9  29.43  12.41  19.03  16.16   78  1034.6       N        1
# 9     10     9  31.57  13.27  24.25  20.95   74  1030.9       S        1
# 10    11     9  33.09  13.30  24.20  20.56   71  1027.9       E        1
# 11    12     9  33.25  14.10  26.49  23.76   80  1024.9      NE        2
# ...

# %%
df.columns=[column.replace(" ","_") for column in df.columns]
df
# Out:
#     Days  Time  Max_T  Min_T  Dry_T  Wet_T  Hum   Press Wind_D.  Wind_St  \
# 0      1     9  26.43  11.78  18.97  16.22   76  1023.9       S        1
# 1      2     9  26.18  18.20  21.54  19.38   82  1016.7      SW        2
# 2      3     9  26.45  17.86  20.23  18.59   85  1016.0     WNW        2
# 3      4     9  21.70  12.89  18.31  15.38   74  1020.0      NW        3
# 4      5     9  20.79  10.02  15.38  13.45   81  1027.4      NW        3
# 5      6     9  23.54   7.32  17.81  15.06   75  1034.9     NNW        2
# 6      7     9  25.51   9.02  12.29  10.72   83  1031.9      NW        2
# 7      8     9  28.49  11.47  20.51  17.57   75  1032.9     NNE        1
# 8      9     9  29.43  12.41  19.03  16.16   78  1034.6       N        1
# 9     10     9  31.57  13.27  24.25  20.95   74  1030.9       S        1
# 10    11     9  33.09  13.30  24.20  20.56   71  1027.9       E        1
# 11    12     9  33.25  14.10  26.49  23.76   80  1024.9      NE        2
# ...

# %%
df.loc[(df['Dry_T']>22.10) & (df['Hum']<88)]
# Out:
#     Days  Time  Max_T  Min_T  Dry_T  Wet_T  Hum   Press Wind_D.  Wind_St  \
# 9     10     9  31.57  13.27  24.25  20.95   74  1030.9       S        1
# 10    11     9  33.09  13.30  24.20  20.56   71  1027.9       E        1
# 11    12     9  33.25  14.10  26.49  23.76   80  1024.9      NE        2
# 12    13     9  33.23  15.27  22.48  19.72   77  1021.2      NE        2
# 13    14     9  33.30  15.98  24.40  21.28   76  1013.2      NE        1
#
#     Cl_am Cl_Ty  Rain  Snow
# 9       0    C.   0.0     0
# 10      0    C.   0.0     0
# 11      0    C.   0.0     0
# 12      0    C.   0.0     0
# 13      1   As.   0.0     0
